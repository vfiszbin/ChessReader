# %% [markdown]
# # Pipeline Test

# %% [markdown]
# ## Image Generation

# %%
from image_setup import *
from image_generation import *
from image_processing import *
from data_generation import *

# %%
move = get_random_move(config_setup)
img, bgc = generate_image(move, config_setup)
img
# Out:
# <PIL.Image.Image image mode=RGB size=180x82>

# %% [markdown]
# ## PostProcessing Test

# %%
add_rotation(img, config_process, bgc)
# Out:
# <PIL.Image.Image image mode=RGB size=180x82>

# %%
add_translation(img, config_process, bgc)
# Out:
# <PIL.Image.Image image mode=RGB size=180x82>

# %%
add_shear(img, config_process, bgc)
# Out:
# <PIL.Image.Image image mode=RGB size=180x82>

# %%
add_perspective(img, config_process, bgc)
# Out:
# <PIL.Image.Image image mode=RGB size=180x82>

# %%
add_zoom(img, config_process, bgc)
# Out:
# <PIL.Image.Image image mode=RGB size=180x82>

# %%
add_brightness(img, config_process, bgc)
# Out:
# <PIL.Image.Image image mode=RGB size=180x82>

# %%
add_gaussian_noise(img, config_process, bgc)
# Out:
# <PIL.Image.Image image mode=RGB size=180x82>

# %%
add_salt_pepper_noise(img, config_process, bgc)
# Out:
# <PIL.Image.Image image mode=RGB size=180x82>

# %%
add_gaussian_blur(img, config_process, bgc)
# Out:
# <PIL.Image.Image image mode=RGB size=178x80>

# %%
new_move = add_character_change(move, config_process, config_characters)
img, bgc = generate_image(new_move, config_setup)
img
# Out:
# <PIL.Image.Image image mode=RGB size=178x80>

# %% [markdown]
# ## Full Pipeline

# %%
move = get_random_move(config_setup)
new_move = add_character_change(move, config_process, config_characters)
img, bgc = generate_image(new_move, config_setup)
img = add_processing(img, config_process, bgc)
img
# Out:
# <PIL.Image.Image image mode=RGB size=197x87>

# %%
# generate_images(100, config_setup, config_process, config_characters)

# %%
for char_list in config_characters.values():
    for char in char_list:
        img, _ = generate_image(char, config_setup, box=True)
        print(char)
        display(img)
# Out:
# a
# <PIL.Image.Image image mode=RGB size=184x76>
# @
# <PIL.Image.Image image mode=RGB size=182x80>
# A
# <PIL.Image.Image image mode=RGB size=178x80>
# b
# <PIL.Image.Image image mode=RGB size=180x76>
# ♭
# <PIL.Image.Image image mode=RGB size=180x86>
# c
# <PIL.Image.Image image mode=RGB size=186x86>
# (
# <PIL.Image.Image image mode=RGB size=184x86>
# C
# <PIL.Image.Image image mode=RGB size=172x80>
# d
# <PIL.Image.Image image mode=RGB size=184x76>
# e
# <PIL.Image.Image image mode=RGB size=176x82>
#  ε
# <PIL.Image.Image image mode=RGB size=178x80>
# E
# <PIL.Image.Image image mode=RGB size=188x76>
# f
# <PIL.Image.Image image mode=RGB size=176x86>
# t
# <PIL.Image.Image image mode=RGB size=180x78>
# F
# <PIL.Image.Image image mode=RGB size=184x76>
# g
# <PIL.Image.Image image mode=RGB size=172x84>
# 9
# <PIL.Image.Image image mode=RGB size=184x80>
# q
# <PIL.Image.Image image mode=RGB size=176x84>
# h
# <PIL.Image.Image image mode=RGB size=184x76>
# n
# ...
